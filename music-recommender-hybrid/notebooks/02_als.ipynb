# %%
from pyspark.sql import SparkSession
from src.als_model import ALSRecommender

spark = SparkSession.builder.appName("ALS Demo").getOrCreate()

# %%
als = ALSRecommender()
model, rmse = als.train()

print("RMSE:", rmse)

# %%
recs = als.recommend_for_user(2, k=10).collect()
recs
