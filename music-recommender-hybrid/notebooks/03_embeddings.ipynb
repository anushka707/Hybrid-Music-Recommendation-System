# %%
from src.embeddings import TrackEmbeddingModel
import numpy as np

# %%
embedder = TrackEmbeddingModel()
embedder.generate_embeddings()

# %%
print(embedder.get_similar_tracks(track_id=10, top_k=5))
